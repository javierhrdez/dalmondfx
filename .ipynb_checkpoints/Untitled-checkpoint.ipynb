# %%
import pandas as pd
from pandas.io.json import json_normalize
import requests

# %%
token = "627bee6f-aec0-47bb-b369-c058e32ec406"
lat , lon = 19.3878814,-99.179302
radio = 250 #mts
condicion = "restaurante"

# %%
url = f'https://www.inegi.org.mx/app/api/denue/v1/consulta/Buscar/{condicion}/{lat},{lon}/{radio}/{token}'

r = requests.get(url)
denue = pd.DataFrame()
datos = r.json()
for dato in datos:
    #print(dato)
    dato = json_normalize(dato)
    denue = denue.append(dato , ignore_index=True)

# %%
denue.head()
# Out:
#       CP                      Calle CentroComercial  \
# 0  03840                    GEORGIA
# 1  03810                    INDIANA
# 2  03810  GEORGIA, ESQ. PENSILVANIA
# 3  03810                    GEORGIA
# 4  03810               PENNSYLVANIA
#
#                                      Clase_actividad             Colonia  \
# 0  Restaurantes que preparan otro tipo de aliment...  AMPLIACION NAPOLES
# 1  Restaurantes con servicio de preparación de an...             NÁPOLES
# 2  Restaurantes con servicio de preparación de pi...             NAPOLES
# 3  Restaurantes con servicio de preparación de pi...             NÁPOLES
# 4  Restaurantes con servicio de preparación de al...             NÁPOLES
#
#                   Correo_e           Estrato       Id      Latitud  \
# 0                            6 a 10 personas   875319  19.38811878
# 1                             0 a 5 personas   932053  19.38859173
# 2                           11 a 30 personas  6313034  19.38852564
# 3  INFO@GIANCARLOPIZZA.COM   6 a 10 personas   869243  19.38868456
# 4                            6 a 10 personas   870908  19.38838872
#
#        Longitud                       ...                       NumLocal  \
# 0  -99.17924278                       ...
# 1  -99.17958739                       ...
# 2  -99.17813091                       ...
# 3  -99.17805169                       ...
# 4  -99.17767122                       ...
#
#   Num_Exterior Num_Interior  \
# 0          158
# 1          193
# 2          120
# 3          123
# 4          190
#
#                                         Razon_social  \
# 0                      GRUPO CHAMBELLE, S.A. DE C.V.
# 1
# 2  OPERADORA Y PROCESADORA DE PRODUCTOS DE PANIFI...
# 3
# 4
#
#                    Sitio_internet      Telefono  Tipo TipoCentroComercial  \
# 0  WWW.CHAMBELLENATURALISSIMO.COM    5556829511  Fijo
# 1                                    5555239535  Fijo
# 2              WWW.DOMINOS.COM.MX  018003664667  Fijo
# 3          WWW.GIANCARLOPIZZA.COM    5555239703  Fijo
# 4                  WWW.NONSOLO.MX    5556870495  Fijo
#
#   Tipo_vialidad                                       Ubicacion
# 0         CALLE  BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
# 1         CALLE  BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
# 2         CALLE  BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
# 3         CALLE  BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
# 4         CALLE  BENITO JUÁREZ, Benito Juárez, CIUDAD DE MÉXICO
#
# [5 rows x 21 columns]

# %%
denue.columns.values
# Out:
# array(['CP', 'Calle', 'CentroComercial', 'Clase_actividad', 'Colonia',
#        'Correo_e', 'Estrato', 'Id', 'Latitud', 'Longitud', 'Nombre',
#        'NumLocal', 'Num_Exterior', 'Num_Interior', 'Razon_social',
#        'Sitio_internet', 'Telefono', 'Tipo', 'TipoCentroComercial',
#        'Tipo_vialidad', 'Ubicacion'], dtype=object)

# %%
denue.to_csv('denue.csv')
